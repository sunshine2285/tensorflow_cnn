# %% [markdown]
# <a href="https://colab.research.google.com/github/sunshine2285/tensorflow_cnn/blob/master/tensorflow_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
import tensorflow.compat.v1 as tf
# import tensorflow as tf
import os

tf.disable_v2_behavior()

#通过一下两个参数决定模型行为
# 训练还是测试
train = False
# 待分类label id
label_classify_list =  [0, 1, 2, 3, 4]

# 数据文件夹
train_data_dir = "/content/drive/My Drive/dataset/cifar-10-jpg/"
test_data_dir = "/content/drive/My Drive/dataset/cifar-10-jpg/test/"

# 模型文件路径
model_path = "/content/drive/My Drive/dataset/model/cifar-10-cnn/"

# label和名称的对照关系
label_name_dict = {
    0: "airplane",
    1: "automobile",
    2: "bird",
    3: "cat",
    4: "deer",
    5: "dog",
    6: "frog",
    7: "horse",
    8: "ship",
    9: "truck"
}

#定义分类数量
class_count = len(label_classify_list)

# 从文件夹中读取图片和标签到numpy数组中
# 标签信息在文件名中，0_99.jpg 表示标签为1
def read_data(data_dir):
    datas = []
    labels = []
    fpaths = []
    if data_dir == train_data_dir:
        for i in label_classify_list:
            for fname in os.listdir(data_dir + "\\" + str(i)):
                fpath = os.path.join(data_dir, fname)
                fpaths.append(fpath)
                image = Image.open(fpath)
                data = np.array(image) / 255.0
                label = int(fname.split("_")[0])
                datas.append(data)
                labels.append(label)
    elif data_dir == test_data_dir:
        for fname in os.listdir(data_dir):
            label = int(fname.split("_")[0])
            if label not in label_classify_list:
                continue
            fpath = os.path.join(data_dir, fname)
            image = Image.open(fpath)
            data = np.array(image) / 255.0
            fpaths.append(fpath)
            datas.append(data)
            labels.append(label)
    datas = np.array(datas)
    labels = np.array(labels)
    print("shape of datas: {}\tshape of labels: {}".format(datas.shape, labels.shape))
    return fpaths, datas, labels


data_dir = test_data_dir
if not train:
    data_dir = test_data_dir


fpaths, datas, labels = read_data(data_dir)


# 计算有多少类图片
num_classes = len(set(labels))

# 定义Placeholder，存放输入和标签
# tf.disable_eager_execution()
tf.reset_default_graph()
datas_placeholder = tf.placeholder(tf.float32, [None, 32, 32, 3])
labels_placeholder = tf.placeholder(tf.int32, [None])

# 定义存放DropOut参数的容器，训练时为0.25，测试时为0
dropout_placeholder = tf.placeholder(tf.float32)

# 定义卷积层，20个卷积核，卷积核大小为5，用Relu激活
conv0 = tf.layers.conv2d(datas_placeholder, 20, 5, activation=tf.nn.relu)
# 定义max-pooling层，pooling窗口为2x2，步长为2x2
pool0 = tf.layers.max_pooling2d(conv0, [2, 2], [2, 2])

# 定义卷积层，40个卷积核，卷积核大小为4，用Relu激活
conv1 = tf.layers.conv2d(pool0, 40, 4, activation=tf.nn.relu)
# 定义max-pooling层，pooling窗口为2x2，步长为2x2
pool1 = tf.layers.max_pooling2d(conv1, [2, 2], [2, 2])

# 将3维特征转换为1维向量
flatten = tf.layers.flatten(pool1)

# 全连接层，转换为长度为400的特征向量
fc = tf.layers.dense(flatten, 400, activation=tf.nn.relu)

# 加上DropOut，防止过拟合
dropout_fc = tf.layers.dropout(fc, dropout_placeholder)

# 未激活的输出层
logits = tf.layers.dense(dropout_fc, num_classes)

predicted_labels = tf.arg_max(logits, 1)

# 利用交叉熵定义损失
losses = tf.nn.softmax_cross_entropy_with_logits(
    labels=tf.one_hot(labels_placeholder, num_classes),
    logits=logits
)

# 平均损失
mean_loss = tf.reduce_mean(losses)

# 定义优化器，指定要优化的损失函数
optimizer = tf.train.AdamOptimizer(learning_rate=1e-2).minimize(losses)

# 用于保存和载入模型

saver = tf.train.Saver()

with tf.Session() as  sess:
    if train:
        print("训练模式")
        # 如果是训练，初始化参数
        sess.run(tf.global_variables_initializer())
        # 定义输入和label一填充容器，训练时dropout为0.25
        train_feed_dict = {
            datas_placeholder: datas,
            labels_placeholder: labels,
            dropout_placeholder: 0.25
        }
        for step in range(500):
            _, mean_loss_val = sess.run([optimizer, mean_loss], feed_dict=train_feed_dict)
            if step % 5 == 0:
                print("step = {}\tmean_loss = {}".format(step, mean_loss_val))
        saver.save(sess, model_path)
        print("训练结束，保存模型到{}".format(model_path))
    else:
        print("测试模式")
        # 如果是测试，载入参数
        saver.restore(sess, model_path)
        print("从{}载入模型".format(model_path))

        # 定义输入和label以填充容器，测试时dropout为0
        test_feed_dict = {
            datas_placeholder: datas,
            # labels_placeholder: labels,
            dropout_placeholder: 0
        }
        predicted_labels_val = sess.run(predicted_labels, feed_dict=test_feed_dict)
        tested_img = 0
        correct_img = 0
        uncorrect_img = 0
        # 真实label与模型预测label名
        for fpath, real_label, predicted_label in zip(fpaths, labels, predicted_labels_val):
            # 将label id转换为label名
            real_label_name = label_name_dict[real_label]
            predicted_label_name = label_name_dict[predicted_label]
            tested_img += 1
            if real_label_name == predicted_label_name:
                correct_img += 1
            else:
                uncorrect_img += 1
            print("{}\t{} => {}".format(fpath, real_label_name, predicted_label_name))
        print("tested img count: {}, correct img: {}, uncorrect img: {}, accuracy: {}".format(
            tested_img, correct_img, uncorrect_img, correct_img / tested_img
        ))
# Out:
# shape of datas: (5000, 32, 32, 3)	shape of labels: (5000,)
# 测试模式
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/dataset/model/cifar-10-cnn/
# 从/content/drive/My Drive/dataset/model/cifar-10-cnn/载入模型
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_0.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_3.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_6.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_8.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_10.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_21.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_22.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_25.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_26.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_27.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_32.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_35.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_36.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_37.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_40.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_44.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_46.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_52.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_53.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_58.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_61.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_63.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_65.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_66.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_67.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_68.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_70.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_74.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_75.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_77.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_78.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_81.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_82.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_84.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_86.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_90.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_91.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_94.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_97.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_98.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_100.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_103.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_104.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_105.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_106.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_110.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_111.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_113.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_114.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_115.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_116.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_117.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_118.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_121.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_122.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_123.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_125.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_127.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_129.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_130.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_131.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_134.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_135.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_138.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_143.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_147.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_149.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_153.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_154.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_156.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_159.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_160.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_161.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_165.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_167.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_169.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_176.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_179.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_180.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_182.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_183.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_184.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_187.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_188.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_189.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_192.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_193.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_195.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_201.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_204.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_205.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_206.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_211.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_215.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_219.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_223.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_224.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_227.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_231.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_235.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_236.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_237.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_240.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_241.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_244.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_245.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_246.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_248.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_249.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_251.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_254.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_255.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_256.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_257.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_258.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_261.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_264.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_266.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_267.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_269.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_270.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_271.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_273.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_276.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_277.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_278.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_279.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_281.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_283.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_284.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_286.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_287.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_290.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_291.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_294.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_295.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_297.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_298.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_302.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_303.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_305.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_307.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_308.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_313.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_314.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_315.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_320.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_322.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_323.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_324.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_325.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_328.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_330.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_332.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_336.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_338.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_340.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_342.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_346.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_351.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_352.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_353.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_354.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_356.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_357.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_359.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_363.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_365.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_366.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_367.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_369.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_370.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_373.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_374.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_376.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_378.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_382.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_384.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_387.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_388.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_390.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_391.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_393.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_396.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_397.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_398.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_399.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_405.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_406.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_407.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_409.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_412.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_414.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_416.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_418.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_420.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_422.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_423.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_424.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_426.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_427.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_428.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_430.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_432.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_434.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_436.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_438.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_439.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_440.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_441.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_447.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_448.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_449.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_450.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_453.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_455.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_456.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_458.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_462.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_463.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_464.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_465.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_466.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_467.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_470.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_473.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_477.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_479.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_489.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_490.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_491.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_493.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_494.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_496.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_497.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_498.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_499.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_500.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_503.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_505.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_509.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_513.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_515.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_522.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_524.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_526.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_527.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_528.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_531.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_537.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_539.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_540.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_546.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_548.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_555.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_557.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_558.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_559.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_560.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_563.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_564.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_565.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_569.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_572.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_573.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_580.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_581.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_583.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_584.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_586.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_587.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_592.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_594.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_595.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_597.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_599.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_602.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_603.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_604.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_606.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_607.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_608.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_618.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_619.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_622.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_623.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_627.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_628.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_629.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_630.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_637.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_638.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_641.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_642.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_645.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_646.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_647.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_648.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_650.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_655.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_656.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_657.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_658.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_659.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_661.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_664.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_667.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_668.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_669.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_671.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_673.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_674.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_675.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_676.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_677.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_678.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_682.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_688.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_689.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_690.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_691.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_692.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_695.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_697.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_701.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_702.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_705.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_706.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_714.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_715.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_716.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_718.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_720.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_723.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_725.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_726.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_727.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_730.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_731.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_735.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_736.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_737.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_738.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_739.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_740.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_742.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_748.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_751.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_753.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_754.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_755.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_758.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_759.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_760.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_763.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_764.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_765.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_767.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_769.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_771.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_773.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_774.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_775.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_776.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_778.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_781.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_785.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_786.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_790.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_791.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_792.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_793.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_796.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_797.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_799.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_801.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_802.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_804.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_805.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_807.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_811.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_813.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_814.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_819.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_821.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_822.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_825.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_829.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_830.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_831.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_832.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_833.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_835.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_836.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_837.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_839.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_841.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_843.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_844.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_845.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_846.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_847.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_848.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_849.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_854.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_857.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_860.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_862.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_863.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_864.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_865.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_866.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_868.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_869.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_870.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_871.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_872.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_873.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_874.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_876.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_877.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_878.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_881.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_882.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_883.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_885.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_886.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_887.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_888.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_889.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_890.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_894.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_895.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_896.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_898.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_900.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_906.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_911.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_912.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_913.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_914.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_915.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_916.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_919.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_928.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_929.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_930.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_931.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_932.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_933.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_935.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_936.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_941.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_943.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_944.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_945.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_946.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_947.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_948.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_950.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_953.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_954.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_956.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_957.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_961.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_962.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_968.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_971.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_972.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_973.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_975.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_978.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_980.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_982.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_983.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_986.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_987.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_988.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_989.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_990.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_993.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_995.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_997.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_998.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1001.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1003.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1005.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1006.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1010.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1013.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1014.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1015.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1016.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1018.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1020.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1021.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1022.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1023.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1024.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1026.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1027.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1030.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1031.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1033.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1036.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1038.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1039.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1043.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1046.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1047.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1048.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1049.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1050.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1051.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1052.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1053.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1054.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1056.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1061.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1063.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1065.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1067.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1070.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1072.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1074.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1076.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1077.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1078.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1083.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1085.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1086.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1088.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1090.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1093.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1095.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1098.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1099.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1103.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1105.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1108.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1109.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1110.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1112.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1115.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1118.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1121.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1123.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1124.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1126.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1128.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1129.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1131.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1132.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1133.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1134.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1137.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1141.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1144.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1145.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1146.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1148.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1150.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1151.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1152.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1156.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1158.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1161.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1163.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1165.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1166.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1167.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1168.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1172.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1173.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1174.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1176.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1179.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1180.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1181.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1182.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1183.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1185.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1186.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1187.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1188.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1189.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1190.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1191.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1194.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1196.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1197.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1202.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1203.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1206.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1207.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1208.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1210.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1212.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1217.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1219.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1227.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1229.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1232.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1233.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1234.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1237.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1238.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1240.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1241.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1247.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1248.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1249.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1251.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1254.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1255.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_1257.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1258.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_1260.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_1266.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_1267.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_1268.jpg	cat => cat
# ...
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9597.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9601.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9602.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9603.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9608.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9609.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9610.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9612.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9613.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9618.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9620.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9624.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9625.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9626.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9627.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9629.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9632.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9633.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9634.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9638.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9639.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9642.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9644.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9645.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9647.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9648.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9656.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9659.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9662.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9663.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9664.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9665.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9666.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9668.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9670.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9675.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9676.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9678.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9679.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9681.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9685.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9686.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9687.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9688.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9690.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9694.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9695.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9696.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9699.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9700.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9701.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9703.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9704.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9709.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9711.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9714.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9715.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9722.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9724.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9728.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9729.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9731.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9734.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9739.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9740.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9744.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9745.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9746.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9747.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9748.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9749.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9750.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9751.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9753.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9755.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9763.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9764.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9765.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9766.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9767.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9770.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9771.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9772.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9776.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9778.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9779.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9780.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9781.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9782.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9783.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9788.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9793.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9794.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9795.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9797.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9800.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9802.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9803.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9805.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9807.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9808.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9809.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9811.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9812.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9813.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9816.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9818.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9819.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9820.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9821.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9822.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9824.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9825.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9826.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9827.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9830.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9831.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9832.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9836.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9837.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9839.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9840.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9841.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9843.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9847.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9848.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9849.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9852.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9857.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9858.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9860.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9862.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9865.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9866.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9870.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9872.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9873.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9874.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9876.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9882.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9886.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9888.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9890.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9891.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9893.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9894.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9895.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9896.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9901.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9904.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9905.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9906.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9907.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9909.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9910.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9911.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9912.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9915.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9916.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9917.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9919.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9921.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9924.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9925.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9926.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9931.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9934.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9935.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9937.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9940.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9941.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9946.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9947.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9949.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9950.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9951.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9954.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9956.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9957.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9959.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9960.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9961.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9962.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9964.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9965.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9967.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9968.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9970.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9972.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9973.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9974.jpg	automobile => automobile
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9979.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9980.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/4_9981.jpg	deer => deer
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9982.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9983.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9987.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/2_9989.jpg	bird => bird
# /content/drive/My Drive/dataset/cifar-10-jpg/test/0_9991.jpg	airplane => airplane
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9992.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9994.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/3_9996.jpg	cat => cat
# /content/drive/My Drive/dataset/cifar-10-jpg/test/1_9998.jpg	automobile => automobile
# tested img count: 5000, correct img: 5000, uncorrect img: 0, accuracy: 1.0

# %%
# !pwd
# !ls -la
# !mv .*
# Out:
# /content/drive/My Drive/dataset/model
# total 9904
# drwx------ 3 root root    4096 Feb 11 11:39 cifar-10-cnn
# -rw------- 1 root root 9983128 Feb 11 09:58 .data-00000-of-00001
# -rw------- 1 root root    1787 Feb 11 09:58 .index
# drwx------ 2 root root    4096 Feb 11 07:55 .ipynb_checkpoints
# -rw------- 1 root root  147886 Feb 11 09:58 .meta
# mv: target '.meta' is not a directory

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 1.15.0

# %%
# 功能：将cifar10的数据集分类生成图片

import matplotlib.pyplot as plt
import numpy as np
import os

def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        data = pickle.load(fo, encoding='bytes')
    return data


dataset_path = "cifar-10-batches-py/"
img_save_path = "cifar-10-jpg/"
file_name_list = ['batches.meta', 'data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5',
                  'test_batch']
generate_train_img = True
generate_test_img = True

# 获取 lable 与 id 的对应关系
def get_lables():
    file_dict = unpickle(dataset_path + file_name_list[0])
    return file_dict[b'label_names']


if __name__ == "__main__":
    print(get_lables())
    if generate_train_img:
        lable_count = np.zeros(10, dtype="int")
        for i in range(1, 6):
            file_data = unpickle(dataset_path + file_name_list[i])
            for j in range(0, 10000):
                img_data = np.reshape(file_data[b'data'][j], (3, 32, 32))
                img_data = img_data.transpose((1, 2, 0))
                lable_id = file_data[b'labels'][j]
                img_name = str(lable_id) + "_" + str(lable_count[lable_id]) + ".jpg"
                if not os.path.exists(img_save_path + str(lable_id)):
                    os.makedirs(img_save_path + str(lable_id))
                plt.imsave(img_save_path + str(lable_id) + "/" + img_name, img_data)
                lable_count[lable_id] += 1
                print('\t', img_name, "saved ……")
            print("【*】---", i, "st dataset_path saved")
    if generate_test_img:
        file_data = unpickle(dataset_path + file_name_list[6])
        for k in range(0, 10000):
            img_data = np.reshape(file_data[b'data'][k], (3, 32, 32))
            img_data = img_data.transpose((1, 2, 0))
            lable_id = file_data[b'labels'][k]
            img_name = str(lable_id) + "_" + str(k) + ".jpg"
            if not os.path.exists(img_save_path + "test/"):
                os.makedirs(img_save_path + "test/")
            plt.imsave(img_save_path + "test/" + img_name, img_data)
            print('\t', img_name, "saved ……")
        print("【*】---", "test dataset_path saved")
    print("*******ALl Task Finished********")

# %%
import requests

if __name__ == '__main__':
    print("downloading with requests")
    url = 'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz'
    r = requests.get(url)
    with open("cifar-10-python.tar.gz", "wb") as code:
        code.write(r.content)
    print("downloading finished")
